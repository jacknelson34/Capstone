# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')

#colab can't access shared folders so I created a folder in my drive and added one of folders from the data
# !ls drive/MyDrive/AgriLifeMicrohistologicalProject/184HD/001/184HD_001.txt

with open('drive/MyDrive/AgriLifeMicrohistologicalProject/184HD/001/184HD_001.txt', newline='') as f: #reads txt file and turns into 2d list
    reader = csv.reader(f, delimiter=' ')
    data = list(reader)

grass = []
holder = []
count = 0

for x in data: #turns all string in 2d list to float
  for y in x:
    holder.append(float(y))
    count += 1

  if count == 5:
    count = 0
    grass.append(holder)
    holder = []


print(grass)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# drive/MyDrive/AgriLifeMicrohistologicalProject/184HD/001/184HD_001.txt
# [[2.0, 0.872217, 0.41954, 0.03418, 0.028945], [3.0, 0.886548, 0.396212, 0.014014, 0.014995], [1.0, 0.67937, 0.537461, 0.0521, 0.062696], [3.0, 0.3646, 0.860162, 0.013672, 0.012905], [3.0, 0.53938, 0.901776, 0.018896, 0.020899], [3.0, 0.554028, 0.925444, 0.013037, 0.014629], [1.0, 0.727856, 0.915543, 0.034521, 0.074869]]

# %%
img = plt.imread('drive/MyDrive/AgriLifeMicrohistologicalProject/184HD/001/184HD_001.png') #gets image data

# %%
height, width = img.shape[0:2] #stores dimensions of image

#used to change what feature in grass image we looking at
ind = 4

#snipping math using txt file numbers
x_min = round((width * grass[ind][1]) - (width * grass[ind][3])/2)
x_max = round((width * grass[ind][1]) + (width * grass[ind][3])/2)
y_min = round((height * grass[ind][2]) - (height * grass[ind][4])/2)
y_max = round((height * grass[ind][2]) + (height * grass[ind][4])/2)
#print(x_min)
#print(x_max)
#print(y_min)
#print(y_max)

img_cropped = img[y_min:y_max, x_min:x_max]

print(img_cropped.shape)

plt.imshow(img_cropped)

if(grass[ind][0] == 0):
  print("Nale")
elif(grass[ind][0] == 1):
  print("Qufu")
elif(grass[ind][0] == 2):
  print("Erci")
elif(grass[ind][0] == 3):
  print("Bubble")
elif(grass[ind][0] == 4):
  print("Qufu stem")
# Out:
# (400, 387, 3)
# Bubble
